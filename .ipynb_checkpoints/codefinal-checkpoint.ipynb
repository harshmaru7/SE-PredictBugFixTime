# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
head=["id","date_time","flag","option"]

temporal_dataset = pd.read_csv("temporal_activity.csv",header=None)
temporal_dataset.columns=head
temporal_dataset["date_time"]=pd.to_datetime(temporal_dataset["date_time"])

compressed_set = temporal_dataset.groupby(['id'])['flag'].apply(lambda x: "%s" % ''.join(x)).reset_index()

# %%
print(compressed_set)
# Out:
#             id        flag
# 0       322067        NWCZ
# 1       322075          NZ
# 2       322077  NAVCVVVYLZ
# 3       322080      NCWCCZ
# 4       322081        NCCZ
# ...        ...         ...
# 86437  1116604      MPQPCZ
# 86438  1116618         NCZ
# 86439  1116656        NCCZ
# 86440  1116679       NQCQZ
# 86441  1116689        NCCZ
#
# [86442 rows x 2 columns]

# %%
temporal_dataset = pd.read_csv("noofdays.csv")

# %%
print(temporal_dataset)
# Out:
#             id  difference of days
# 0       322067                 549
# 1       322075                   0
# 2       322077                 303
# 3       322080                1333
# 4       322081                 521
# ...        ...                 ...
# 86438  1116604                   0
# 86439  1116618                   0
# 86440  1116656                   3
# 86441  1116679                  14
# 86442  1116689                  12
#
# [86443 rows x 2 columns]

# %%
final = pd.merge(compressed_set,temporal_dataset,on="id",how="outer")

# %%
print(final)
# Out:
#             id        flag  difference of days
# 0       322067        NWCZ                 549
# 1       322075          NZ                   0
# 2       322077  NAVCVVVYLZ                 303
# 3       322080      NCWCCZ                1333
# 4       322081        NCCZ                 521
# ...        ...         ...                 ...
# 86438  1116618         NCZ                   0
# 86439  1116656        NCCZ                   3
# 86440  1116679       NQCQZ                  14
# 86441  1116689        NCCZ                  12
# 86442   455694         NaN                1043
#
# [86443 rows x 3 columns]

# %%
final.drop(final.tail(1).index,inplace=True) # drop last n rows

# %%
print(final)
# Out:
#             id        flag  difference of days
# 0       322067        NWCZ                 549
# 1       322075          NZ                   0
# 2       322077  NAVCVVVYLZ                 303
# 3       322080      NCWCCZ                1333
# 4       322081        NCCZ                 521
# ...        ...         ...                 ...
# 86437  1116604      MPQPCZ                   0
# 86438  1116618         NCZ                   0
# 86439  1116656        NCCZ                   3
# 86440  1116679       NQCQZ                  14
# 86441  1116689        NCCZ                  12
#
# [86442 rows x 3 columns]

# %%
final.plot(x='flag', y='difference of days', style='o')  
plt.title('Flag vs Time Taken')  
plt.xlabel('Flags')  
plt.ylabel('Time Taken-Day')  
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(final['difference of days'])

# %%
final.flag = pd.Categorical(final.flag)
final['code'] = final.flag.cat.codes

# %%
# prepare input data
final.flag = pd.Categorical(final.flag)

# %%
print(final)
# Out:
#             id        flag  difference of days   code
# 0       322067        NWCZ                 549  15606
# 1       322075          NZ                   0  15768
# 2       322077  NAVCVVVYLZ                 303  10496
# 3       322080      NCWCCZ                1333  13039
# 4       322081        NCCZ                 521  12166
# ...        ...         ...                 ...    ...
# 86437  1116604      MPQPCZ                   0   9509
# 86438  1116618         NCZ                   0  13192
# 86439  1116656        NCCZ                   3  12166
# 86440  1116679       NQCQZ                  14  14658
# 86441  1116689        NCCZ                  12  12166
#
# [86442 rows x 4 columns]

# %%
X = final['code'].values.reshape(-1,1)
y = final['difference of days'].values.reshape(-1,1)

# %%
trainx = final.iloc[0:51800]

# %%
trainx
# Out:
#            id        flag  difference of days   code
# 0      322067        NWCZ                 549  15606
# 1      322075          NZ                   0  15768
# 2      322077  NAVCVVVYLZ                 303  10496
# 3      322080      NCWCCZ                1333  13039
# 4      322081        NCCZ                 521  12166
# ...       ...         ...                 ...    ...
# 51795  597862         NCZ                   1  13192
# 51796  597867         MCZ                  95   8587
# 51797  597869      NPPCCZ                  76  14427
# 51798  597877       MCCCZ                 252   7688
# 51799  597880          MZ                   0  10276
#
# [51800 rows x 4 columns]

# %%
testx = final.iloc[51800:]

# %%
testx
# Out:
#             id             flag  difference of days   code
# 51800   597896        EDCCCCCCZ                 339   3853
# 51801   597899               MZ                 100  10276
# 51802   597901  MCACCAVYCCVYCLZ                   4   6906
# 51803   597905           NCCWCZ                  80  12099
# 51804   597917               MZ                   0  10276
# ...        ...              ...                 ...    ...
# 86437  1116604           MPQPCZ                   0   9509
# 86438  1116618              NCZ                   0  13192
# 86439  1116656             NCCZ                   3  12166
# 86440  1116679            NQCQZ                  14  14658
# 86441  1116689             NCCZ                  12  12166
#
# [34642 rows x 4 columns]

# %%
#sorted according time taken
sortedmedian = trainx.sort_values(by=['difference of days'])

# %%
sortedmedian
# Out:
#            id                                               flag  \
# 51799  597880                                                 MZ
# 20934  417150                                                 NZ
# 47443  565574                                                ECZ
# 20929  417137                                                 NZ
# 20926  417123                                                NCZ
# ...       ...                                                ...
# 2658   333200                                              MCCCZ
# 3508   336917                                     MCCCCPCCWRCCCZ
# 3496   336869                                              NCCCZ
# 33     322206  NDCCCCCCCCCCCCCCCCRCDCCCCCCCWCCCCCCCCCCCCCCCCD...
# 1563   328840                                           NCCCCCCZ
#
#        difference of days   code
# 51799                   0  10276
# 20934                   0  15768
# 47443                   0   3461
# 20929                   0  15768
# ...

# %%
trainx['difference of days'].median()
# Out:
# 26.0

# %%
lessthanmedian = trainx.loc[trainx['difference of days'] <27]

# %%
lessthanmedian
# Out:
#            id   flag  difference of days   code
# 1      322075     NZ                   0  15768
# 5      322094    NCZ                   1  13192
# 7      322101    NWZ                   0  15740
# 10     322117  NCCCZ                   7  11686
# 11     322119    NCZ                   0  13192
# ...       ...    ...                 ...    ...
# 51784  597815    NCZ                   0  13192
# 51791  597846    NCZ                   0  13192
# 51792  597853    NCZ                   0  13192
# 51795  597862    NCZ                   1  13192
# 51799  597880     MZ                   0  10276
#
# [26011 rows x 4 columns]

# %%
morethanmedian = trainx.loc[trainx['difference of days'] >26]

# %%
morethanmedian
# Out:
#            id        flag  difference of days   code
# 0      322067        NWCZ                 549  15606
# 2      322077  NAVCVVVYLZ                 303  10496
# 3      322080      NCWCCZ                1333  13039
# 4      322081        NCCZ                 521  12166
# 6      322096      NCQWCZ                 521  12665
# ...       ...         ...                 ...    ...
# 51793  597854        MCCZ                 152   7969
# 51794  597861        ECCZ                  35   2494
# 51796  597867         MCZ                  95   8587
# 51797  597869      NPPCCZ                  76  14427
# 51798  597877       MCCCZ                 252   7688
#
# [25789 rows x 4 columns]

# %%
Xlm_train = lessthanmedian['code'].values.reshape(-1,1)
ylm_train = lessthanmedian['difference of days'].values.reshape(-1,1)

# %%
#training the model with time less than median
#Xlm_train,ylm_train = train_test_split(Xlm,ylm,test_size=0.2,random_state=0)

# %%
regressorlm = LinearRegression()  
regressorlm.fit(Xlm_train, ylm_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To retrieve the intercept:
print(regressorlm.intercept_)
# Out:
# [6.37692793]

# %%
#For retrieving the slope:
print(regressorlm.coef_)
# Out:
# [[-0.00034192]]

# %%
Xmm_train = morethanmedian['code'].values.reshape(-1,1)
ymm_train = morethanmedian['difference of days'].values.reshape(-1,1)

# %%
regressormm = LinearRegression()  
regressormm.fit(Xmm_train, ymm_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(regressormm.intercept_)
# Out:
# [303.64710446]

# %%
print(regressormm.coef_)
# Out:
# [[0.01679144]]

# %%
X_test = testx['code'].values.reshape(-1,1)
y_test = testx['difference of days'].values.reshape(-1,1)

# %%
y_pred = regressorlm.predict(X_test)

# %%
dfo = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted1': y_pred.flatten()})
dfo
# Out:
#        Actual  Predicted1
# 0         339    5.059527
# 1         100    2.863402
# 2           4    4.015658
# 3          80    2.240089
# 4           0    2.863402
# ...       ...         ...
# 34637       0    3.125651
# 34638       0    1.866375
# 34639       3    2.217181
# 34640      14    1.365127
# 34641      12    2.217181
#
# [34642 rows x 2 columns]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 48.737715546509506
# Mean Squared Error: 12754.779050894236
# Root Mean Squared Error: 112.93705791676281

# %%
y_pred = regressormm.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
# Out:
#        Actual   Predicted
# 0         339  368.344511
# 1         100  476.195910
# 2           4  419.608768
# 3          80  506.806700
# 4           0  476.195910
# ...       ...         ...
# 34637       0  463.316878
# 34638       0  525.159740
# 34639       3  507.931726
# 34640      14  549.775987
# 34641      12  507.931726
#
# [34642 rows x 2 columns]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 439.2031944907589
# Mean Squared Error: 205670.99717012845
# Root Mean Squared Error: 453.5096439659563

# %%
answers = pd.merge(dfo,df,on="Actual",how="inner")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-189-671f7f576347> in <module>
# ----> 1 answers = pd.merge(dfo,df,on="Actual",how="inner")
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     641             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     642
# --> 643         join_index, left_indexer, right_indexer = self._get_join_info()
#     644
#     645         ldata, rdata = self.left._data, self.right._data
#
# ...

# %%
answers
